# %% [markdown]
# <h2 align="center"> Google Search Analysis</h2>

# %% [markdown]
# # Google Trends provides an API that can be used to analyze the daily searches on Google. This API is known as pytrends, you can easily install it in your systems by using the pip command.
#
# # pip install pytrends.

# %%
import pandas as pd
from pytrends.request import TrendReq
import matplotlib.pyplot as plt
trends = TrendReq()

# %% [markdown]
# # This analysis focuses on Google search trends for the query "Data Science."
# # Creating a DataFrame of the top 10 countries that search for "Data Science" on Google.

# %%
trends.build_payload(kw_list=["Data Science"])
data = trends.interest_by_region()
data = data.sort_values(by="Data Science", ascending=False)
data = data.head(10)
print(data)
# Out:
#            Data Science
# geoName
# India               100
# Kenya                90
# Singapore            84
# Ethiopia             83
# Nigeria              81
# China                80
# Sri Lanka            66
# Ghana                66
# Pakistan             65
# Nepal                64

# %% [markdown]
# # According to the above results, most "Data Science" search queries are from India.
# # This data can also be visualized using a bar chart.

# %%
data.reset_index().plot(x="geoName", 
                        y="Data Science", 
                        figsize=(15,12), kind="bar")
plt.style.use('fivethirtyeight')
plt.show()

# %% [markdown]
# # Data Science has been a focus for many companies and students over the last 3-4 years.
# # Let's examine the trend of searches to see how the total "Data Science" search queries
# # have increased or decreased on Google.

# %%
data = TrendReq(hl='en-US', tz=360)
data.build_payload(kw_list=['Data Science'])
data = data.interest_over_time()
fig, ax = plt.subplots(figsize=(15, 12))
data['Data Science'].plot()
plt.style.use('fivethirtyeight')
plt.title('Total Google Searches for Data Science', 
          fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Total Count')
plt.show()

# %% [markdown]
# # Summary
# # The graph shows a rising trend in Google searches for "Data Science" from 2020 to 2024, with significant peaks in 2022 and 2023, indicating increasing interest and periodic spikes in search activity.
